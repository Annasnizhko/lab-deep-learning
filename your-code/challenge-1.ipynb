# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](tttboard.jpg)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
# your code here
import pandas as pd

# Load the dataset
df = pd.read_csv('./tic-tac-toe.csv')

# %%
df.head()
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True

# %%
# Convert categorical values to numeric
df.replace({'x': 1, 'o': -1, 'b': 0}, inplace=True)

# %%
# Separate inputs and output
X = df.iloc[:, :-1]  # All columns except the last
y = df.iloc[:, -1]   # Last column as output

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the input data
X_normalized = scaler.fit_transform(X)

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
# your code here
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a Sequential model
model = Sequential()

# Add layers to the model
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))  # Input layer
model.add(Dense(32, activation='relu'))  # Hidden layer
model.add(Dense(16, activation='relu'))  # Hidden layer
model.add(Dense(3, activation='softmax'))  # Output layer (3 classes: -1, 0, 1)
# Out:
# 2024-09-13 12:59:49.404582: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-13 13:00:40.676863: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 22ms/step - loss: 1.1149 - accuracy: 0.3464 - val_loss: 1.0351 - val_accuracy: 0.6688
# Epoch 2/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.9778 - accuracy: 0.6732 - val_loss: 0.8836 - val_accuracy: 0.7078
# Epoch 3/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7949 - accuracy: 0.6520 - val_loss: 0.6790 - val_accuracy: 0.6818
# Epoch 4/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6515 - accuracy: 0.6487 - val_loss: 0.5880 - val_accuracy: 0.6948
# Epoch 5/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5918 - accuracy: 0.6895 - val_loss: 0.5606 - val_accuracy: 0.7532
# Epoch 6/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5628 - accuracy: 0.7500 - val_loss: 0.5406 - val_accuracy: 0.7662
# Epoch 7/100
# ...

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0353 - accuracy: 0.9896
# Test Loss: 0.0353, Test Accuracy: 0.9896

# %%
# Save the model
model.save('tic-tac-toe.model')
# Out:
# INFO:tensorflow:Assets written to: tic-tac-toe.model/assets

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
# your code here
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('tic-tac-toe.model')

# %%
import numpy as np

# Select a few random rows from the test dataset
random_indices = np.random.choice(X_test.shape[0], size=5, replace=False)
random_samples = X_test[random_indices]

# Make predictions
predictions = model.predict(random_samples)
predicted_classes = np.argmax(predictions, axis=1)  # Get the index of the highest probability
# Out:
# 1/1 [==============================] - 0s 190ms/step

# %%
# Get the actual labels for the random samples
actual_classes = y_test.iloc[random_indices].values

# Display the results
for i in range(len(random_samples)):
    print(f"Sample {i+1}:")
    print(f"  Features: {random_samples[i]}")
    print(f"  Predicted Class: {predicted_classes[i]}")
    print(f"  Actual Class: {actual_classes[i]}")
    print()
# Out:
# Sample 1:
#   Features: [0.5 0.5 1.  0.5 1.  0.  1.  0.5 0. ]
#   Predicted Class: 1
#   Actual Class: True
#
# Sample 2:
#   Features: [0.5 0.  1.  1.  1.  0.  1.  0.5 0. ]
#   Predicted Class: 1
#   Actual Class: True
#
# Sample 3:
#   Features: [0.  1.  0.5 1.  1.  0.5 0.  1.  0. ]
#   Predicted Class: 1
#   Actual Class: True
#
# Sample 4:
#   Features: [0.5 0.5 1.  0.  0.  1.  1.  0.  1. ]
#   Predicted Class: 1
#   Actual Class: True
#
# Sample 5:
#   Features: [1.  1.  0.5 1.  1.  0.  0.  0.  0. ]
#   Predicted Class: 0
#   Actual Class: False

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
# Evaluate the model to check current performance
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Current Test Loss: {test_loss:.4f}, Current Test Accuracy: {test_accuracy:.4f}')# your code here
# Out:
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9896
# Current Test Loss: 0.0353, Current Test Accuracy: 0.9896

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Step 1: Define the model
improved_model = Sequential()
improved_model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))  # Input layer
improved_model.add(Dense(64, activation='relu'))  # Hidden layer
improved_model.add(Dense(32, activation='relu'))  # Hidden layer
improved_model.add(Dense(3, activation='softmax'))  # Output layer

# Step 2: Compile the model
learning_rate = 0.001  # You can experiment with this value
optimizer = Adam(learning_rate=learning_rate)

improved_model.compile(optimizer=optimizer,
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# Step 3: Fit the model
history = improved_model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2)

# Step 4: Evaluate the model
improved_test_loss, improved_test_accuracy = improved_model.evaluate(X_test, y_test)
print(f'Improved Test Loss: {improved_test_loss:.4f}, Improved Test Accuracy: {improved_test_accuracy:.4f}')
# Out:
# Epoch 1/200
# 20/20 [==============================] - 1s 23ms/step - loss: 0.7641 - accuracy: 0.6732 - val_loss: 0.6025 - val_accuracy: 0.6818
# Epoch 2/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5782 - accuracy: 0.7042 - val_loss: 0.5588 - val_accuracy: 0.7597
# Epoch 3/200
# 20/20 [==============================] - 0s 20ms/step - loss: 0.5322 - accuracy: 0.7402 - val_loss: 0.5433 - val_accuracy: 0.7532
# Epoch 4/200
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5147 - accuracy: 0.7418 - val_loss: 0.5596 - val_accuracy: 0.7143
# Epoch 5/200
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5037 - accuracy: 0.7288 - val_loss: 0.5188 - val_accuracy: 0.7727
# Epoch 6/200
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4685 - accuracy: 0.7680 - val_loss: 0.5034 - val_accuracy: 0.7792
# Epoch 7/200
# ...

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %% [markdown]
# # your answer here
# The changes I made to improve the model, such as adding more layers and adjusting the learning rate, have not resulted in better performance compared to the original model. In fact, the improved model has a higher test loss and slightly lower test accuracy than the original model.
